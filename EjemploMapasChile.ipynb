# %% [markdown]
# Sitios útiles para Chile:
#
# https://www.bcn.cl/siit/mapas_vectoriales
#
# http://geoine-ine-chile.opendata.arcgis.com

# %%
from geopandas import *
import statsmodels.formula.api as sm
import matplotlib.pyplot as plt
from plotnine import *

# %%
# https://geoine-ine-chile.opendata.arcgis.com/datasets/1c64fcb18f5a41e088b25ef9f42b58d7_0?geometry=159.565%2C-59.306%2C24.565%2C-12.460
censo=GeoDataFrame.from_file('mapas/censo2017Comuna.shp')

# %%
censo
# Out:
#      OBJECTID REGION                                         NOM_REGION  \
# 0           1     12     REGIÓN DE MAGALLANES Y DE LA ANTÁRTICA CHILENA
# 1           2      2                              REGIÓN DE ANTOFAGASTA
# 2           3     12     REGIÓN DE MAGALLANES Y DE LA ANTÁRTICA CHILENA
# 3           4     11  REGIÓN DE AYSÉN DEL GENERAL CARLOS IBÁÑEZ DEL ...
# 4           5     12     REGIÓN DE MAGALLANES Y DE LA ANTÁRTICA CHILENA
# ..        ...    ...                                                ...
# 340       341      2                              REGIÓN DE ANTOFAGASTA
# 341       342     13                   REGIÓN METROPOLITANA DE SANTIAGO
# 342       343     13                   REGIÓN METROPOLITANA DE SANTIAGO
# 343       344     13                   REGIÓN METROPOLITANA DE SANTIAGO
# 344       345     13                   REGIÓN METROPOLITANA DE SANTIAGO
#
#     PROVINCIA        NOM_PROVIN COMUNA     NOM_COMUNA  T_HOM_R  T_MUJ_R  \
# ...

# %%
ggplot(censo[censo['PROVINCIA']=='131'], aes(fill='T_POB'))\
+ geom_map()
# Out:
# <ggplot: (322071257)>

# %%
censo[censo['REGION']=='13']
# Out:
#      OBJECTID REGION                        NOM_REGION PROVINCIA  NOM_PROVIN  \
# 53         54     13  REGIÓN METROPOLITANA DE SANTIAGO       135   MELIPILLA
# 90         91     13  REGIÓN METROPOLITANA DE SANTIAGO       135   MELIPILLA
# 128       129     13  REGIÓN METROPOLITANA DE SANTIAGO       135   MELIPILLA
# 169       170     13  REGIÓN METROPOLITANA DE SANTIAGO       132  CORDILLERA
# 175       176     13  REGIÓN METROPOLITANA DE SANTIAGO       133   CHACABUCO
# 206       207     13  REGIÓN METROPOLITANA DE SANTIAGO       134       MAIPO
# 209       210     13  REGIÓN METROPOLITANA DE SANTIAGO       132  CORDILLERA
# 229       230     13  REGIÓN METROPOLITANA DE SANTIAGO       135   MELIPILLA
# 237       238     13  REGIÓN METROPOLITANA DE SANTIAGO       136   TALAGANTE
# 238       239     13  REGIÓN METROPOLITANA DE SANTIAGO       136   TALAGANTE
# 267       268     13  REGIÓN METROPOLITANA DE SANTIAGO       136   TALAGANTE
# ...

# %%
censo['REGION']
# Out:
# 0      12
# 1       2
# 2      12
# 3      11
# 4      12
#        ..
# 340     2
# 341    13
# 342    13
# 343    13
# 344    13
# Name: REGION, Length: 345, dtype: object

# %% [markdown]
# # COVID en Chile
#
# https://www.gob.cl/coronavirus/cifrasoficiales/
